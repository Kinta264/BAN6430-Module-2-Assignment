# %%
import pandas as pd

# %%
input_txt_file = 'dataset.txt'

# %%
output_csv_file = 'dataset.csv'

# %%
df = pd.read_csv(input_txt_file, sep=',')

# %%
df.head()
# Out:
#    custID        custName   Age Product DatePurchased  Price  RatingOfProduct  \
# 0       1        John Doe  30.0   Shirt    2015-01-10  25.99              4.5
# 1       2      Jane Smith  28.0   Shoes    2015-02-15  59.99              3.8
# 2       3  Robert Johnson   NaN     Hat    2015-03-20  12.99              4.2
# 3       4  Sarah Williams  35.0   Jeans    2015-04-05  39.99              4.0
# 4       5   Michael Brown  32.0   Shirt    2015-05-12    NaN              3.5
#
#   AdvertisingAgency
# 0      Social Media
# 1                TV
# 2        Newspapers
# 3               NaN
# 4      Social Media

# %%
df.to_csv(output_csv_file, index=False)

# %%
print(f"Data from '{input_txt_file}' saved to '{output_csv_file}' successfully.")
# Out:
# Data from 'dataset.txt' saved to 'dataset.csv' successfully.

# %%
df = pd.read_csv(input_txt_file, sep=',')

# %%
df
# Out:
#     custID          custName   Age Product DatePurchased  Price  \
# 0        1          John Doe  30.0   Shirt    2015-01-10  25.99
# 1        2        Jane Smith  28.0   Shoes    2015-02-15  59.99
# 2        3    Robert Johnson   NaN     Hat    2015-03-20  12.99
# 3        4    Sarah Williams  35.0   Jeans    2015-04-05  39.99
# 4        5     Michael Brown  32.0   Shirt    2015-05-12    NaN
# ..     ...               ...   ...     ...           ...    ...
# 95      96      Isabella Lee  35.0   Shirt    2014-10-02  18.99
# 96      97       Noah Turner  27.0   Shoes           NaN  99.99
# 97      98        Mia Miller  38.0   Jeans    2014-11-16  44.99
# 98      99  Charlotte Wilson  36.0   Shirt    2014-12-23  26.99
# 99     100       Mason Davis  27.0   Shoes    2013-01-30  79.99
#
#     RatingOfProduct AdvertisingAgency
# 0               4.5      Social Media
# 1               3.8                TV
# 2               4.2        Newspapers
# 3               4.0               NaN
# ...

# %%
df.drop_duplicates()
# Out:
#     custID          custName   Age Product DatePurchased  Price  \
# 0        1          John Doe  30.0   Shirt    2015-01-10  25.99
# 1        2        Jane Smith  28.0   Shoes    2015-02-15  59.99
# 2        3    Robert Johnson   NaN     Hat    2015-03-20  12.99
# 3        4    Sarah Williams  35.0   Jeans    2015-04-05  39.99
# 4        5     Michael Brown  32.0   Shirt    2015-05-12    NaN
# ..     ...               ...   ...     ...           ...    ...
# 95      96      Isabella Lee  35.0   Shirt    2014-10-02  18.99
# 96      97       Noah Turner  27.0   Shoes           NaN  99.99
# 97      98        Mia Miller  38.0   Jeans    2014-11-16  44.99
# 98      99  Charlotte Wilson  36.0   Shirt    2014-12-23  26.99
# 99     100       Mason Davis  27.0   Shoes    2013-01-30  79.99
#
#     RatingOfProduct AdvertisingAgency
# 0               4.5      Social Media
# 1               3.8                TV
# 2               4.2        Newspapers
# 3               4.0               NaN
# ...

# %%
df
# Out:
#     custID          custName   Age Product DatePurchased  Price  \
# 0        1          John Doe  30.0   Shirt    2015-01-10  25.99
# 1        2        Jane Smith  28.0   Shoes    2015-02-15  59.99
# 2        3    Robert Johnson   NaN     Hat    2015-03-20  12.99
# 3        4    Sarah Williams  35.0   Jeans    2015-04-05  39.99
# 4        5     Michael Brown  32.0   Shirt    2015-05-12    NaN
# ..     ...               ...   ...     ...           ...    ...
# 95      96      Isabella Lee  35.0   Shirt    2014-10-02  18.99
# 96      97       Noah Turner  27.0   Shoes           NaN  99.99
# 97      98        Mia Miller  38.0   Jeans    2014-11-16  44.99
# 98      99  Charlotte Wilson  36.0   Shirt    2014-12-23  26.99
# 99     100       Mason Davis  27.0   Shoes    2013-01-30  79.99
#
#     RatingOfProduct AdvertisingAgency
# 0               4.5      Social Media
# 1               3.8                TV
# 2               4.2        Newspapers
# 3               4.0               NaN
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#     custID       custName   Age Product DatePurchased  Price  RatingOfProduct  \
# 0        1       John Doe  30.0   Shirt    2015-01-10  25.99              4.5
# 1        2     Jane Smith  28.0   Shoes    2015-02-15  59.99              3.8
# 5        6     Lisa Davis  45.0   Shoes    2015-06-18  89.99              4.8
# 9       10   Amy Thompson  29.0   Jeans    2015-10-21  37.99              3.9
# 10      11     Adam Clark  33.0   Shirt    2015-11-28  22.99              4.3
# ..     ...            ...   ...     ...           ...    ...              ...
# 93      94   Olivia Brown  31.0   Shoes    2014-07-18  89.99              4.9
# 94      95  Liam Anderson  33.0   Jeans    2014-08-25  49.99              4.0
# 95      96   Isabella Lee  35.0   Shirt    2014-10-02  18.99              4.4
# 97      98     Mia Miller  38.0   Jeans    2014-11-16  44.99              4.2
# 99     100    Mason Davis  27.0   Shoes    2013-01-30  79.99              4.8
#
#    AdvertisingAgency
# ...

# %%
df=df.reset_index(drop=True)
df
# Out:
#     custID       custName   Age Product DatePurchased  Price  RatingOfProduct  \
# 0        1       John Doe  30.0   Shirt    2015-01-10  25.99              4.5
# 1        2     Jane Smith  28.0   Shoes    2015-02-15  59.99              3.8
# 2        6     Lisa Davis  45.0   Shoes    2015-06-18  89.99              4.8
# 3       10   Amy Thompson  29.0   Jeans    2015-10-21  37.99              3.9
# 4       11     Adam Clark  33.0   Shirt    2015-11-28  22.99              4.3
# ..     ...            ...   ...     ...           ...    ...              ...
# 63      94   Olivia Brown  31.0   Shoes    2014-07-18  89.99              4.9
# 64      95  Liam Anderson  33.0   Jeans    2014-08-25  49.99              4.0
# 65      96   Isabella Lee  35.0   Shirt    2014-10-02  18.99              4.4
# 66      98     Mia Miller  38.0   Jeans    2014-11-16  44.99              4.2
# 67     100    Mason Davis  27.0   Shoes    2013-01-30  79.99              4.8
#
#    AdvertisingAgency
# ...

# %%
df.to_csv(output_csv_file, index=False)

# %%
print(f"Data from '{input_txt_file}' saved to '{output_csv_file}' successfully.")
# Out:
# Data from 'dataset.txt' saved to 'dataset.csv' successfully.
